# %% [markdown]
# ## Aula do dia 04/09/2026
#
# Hoje, iremos aprender a trabalhar com células Python. As células Python executam códigos Python dentro dos notebooks.
# Observe a célula Python abaixo:

# %%
nome = "Alex Machado"
texto = "Essa é uma célula Python escrita pelo melhor programador de todos os tempos: {nome} 🤡!"

print(texto)
# Out:
# Essa é uma célula Python escrita pelo melhor programador de todos os tempos: {nome} 🤡!

# %% [markdown]
# A célula Python também permite códigos de entrada de dados. Veja:

# %%
nome = input("informe seu nome: ").strip().title()
print(nome)
# Out:
# Wallace

# %% [markdown]
# As células Python são acumulativas, e reconhecem as variáveis das células anteriores.
#
# Observe, por exemplo , a célula abaixo:

# %%
n1 = 5
print(f"O valor da variável n1 é: {n1}")
# Out:
# O valor da variável n1 é: 5

# %% [markdown]
# O valor de n1 é claramente 5. Porém, veja na proxima celula e diga qual será o valor da variavel result:

# %%
result = 15 + n1
print(result)
# Out:
# 20

# %% [markdown]
# O valor de result é 20, pois está somando 15 com n1, que tinha valor de 5.
# mas agora observe a célula abaixo sem executá-la:

# %%
x = 10

# %% [markdown]
# Agora, faça o código abaixo na próxima célula, execute e veja qual é o result:

# %%
result = 25 + x
print(result)
# Out:
# 35
